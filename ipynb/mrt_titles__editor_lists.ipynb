# %%
import os
import pandas as pd
import numpy  as np
from datetime import datetime

# %%
############################################ 
### import dwh_titles__editor_lists
############################################
data_path = r"G:/My Drive/cast_and_crew/rpi/prod/transformations/"
import_file = os.path.join(data_path, "dwh_titles__editor_lists.csv")

dwh_titles__editor_lists = pd.DataFrame()
dwh_titles__editor_lists = pd.read_csv (import_file, encoding='utf-8', index_col=0)
print(dwh_titles__editor_lists.shape)
dwh_titles__editor_lists.tail(3)
# Out:
# (5610, 11)
#           tconst              Title Description             Directors  \
# 5607  tt27817389    The Last Viking         NaN  Anders Thomas Jensen
# 5608  tt27714581  Sentimental Value         NaN         Joachim Trier
# 5609  tt35231039             Kokuho         NaN           Sang-il Lee
#
#                     Genres Release Date  \
# 5607  Comedy, Crime, Drama   2025-10-09
# 5608                 Drama   2025-08-20
# 5609                 Drama   2025-11-21
#
#                                          URL festival_name  festival_year  \
# 5607  https://www.imdb.com/title/tt27817389/           YTD           2025
# 5608  https://www.imdb.com/title/tt27714581/           YTD           2025
# 5609  https://www.imdb.com/title/tt35231039/           YTD           2025
#
#                                    festival_url  rec_cnt
# 5607  https://www.kulturinfo.ch/kino/index.html        1
# 5608  https://www.kulturinfo.ch/kino/index.html        1
# 5609  https://www.kulturinfo.ch/kino/index.html        1

# %%
# lst = ['nm0000001', 'nm0000002']
# N_unique =N_unique.query('nconst in @lst')
# N_unique.to_csv('data/nconst.csv' , header=0 , encoding='utf-8')

# T --> cln_imdb__xref_titles_principals_filtered

import os
 
# data_path = r"G:/My Drive/cast_and_crew/rpi/prod/interfaces/rpi2000_twb__principals/export/current/"
data_path = r"G:/My Drive/cast_and_crew/rpi/prod/interfaces/rpi20003_twb__cast_and_crew/export/current/"
output_file = os.path.join(data_path, "mrt_titles__editor_lists.csv")
# output_file = os.path.join(data_path, "rpi20002_twb__principals_per_rating_category.csv")
dwh_titles__editor_lists.to_csv(output_file, encoding="utf-8")
